# %%
import librosa
import librosa.display
import IPython.display as ipd
from IPython.core.display import display
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
import pandas as pd
import os
from random import randint

# %% [markdown]
# # Visualise evaluation dataset
#
# Note: We use randomly generated labels first to fit the OneHotEncoder() that will be used later on

# %%
test_path = "NLP Final Evaluation Dataset/NLP"

file_name = []
emotion_guess = []
emotion_list = ['angry', 'fear', 'happy', 'neutral', 'sad']

for file in os.listdir(test_path):
  audio_file = test_path + '/' + file
  if (file[-3:] == "wav"):
    file_name.append(file)
    emotion_guess.append(emotion_list[randint(0,4)]) #dummy values but is never used

# dataframe for file name
name_df = pd.DataFrame(file_name, columns=['FileName'])

# add another column for emotions prediction and concat
emotion_df = pd.DataFrame(emotion_guess, columns=['Emotion'])
test_df = pd.concat([name_df, emotion_df], axis=1)

test_df.tail(10)
# Out:
#            FileName  Emotion
# 690  fdf37bbd11.wav  neutral
# 691  fe3c41f573.wav     fear
# 692  fe96772cca.wav    angry
# 693  fed46ebc2f.wav     fear
# 694  feeef44bf3.wav     fear
# 695  ff1ef342b5.wav    angry
# 696  ff495c9312.wav     fear
# 697  ff85bf9fd5.wav      sad
# 698  ff9f3fe0b8.wav      sad
# 699  ffe72dcaa1.wav  neutral

# %% [markdown]
# # Feature extraction
#
# At each time t, a vector of length 20 is produced. Therefore, for each sample, we have a 2D matrix. Each sample has different durations, so the matrix has the dimensions 20 x t. We need to make sure that each feature has the same dimensions though padding or truncating.

# %%
# Each feature is a 2D matrix
# We need to make sure that each feature has the same dimensions though padding or truncating

def pad_or_cut(matrix, desired_height, desired_width):
    h = matrix.shape[0]
    w = matrix.shape[1]
    if h <= desired_height:
        matrix = np.pad(matrix, pad_width=((0, desired_height - h)), mode='constant')
    else:
        matrix = matrix[:desired_height, :]
    if w <= desired_width:
        matrix = np.pad(matrix, pad_width=((0, 0), (0, desired_width - w)), mode='constant')
    else:
        matrix = matrix[:, :desired_width]

    return matrix

# Test pad_or_cut
temp_mat = np.arange(24).reshape((4, 6))
assert pad_or_cut(temp_mat, 5, 5).shape == (5,5)

def get_features(path):
    # duration and offset are used to take care of the no audio in start and the ending of each audio files as seen above.
    data, sample_rate = librosa.load(path, offset=0.1)
    res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))    
    return pad_or_cut(res, 20, 120)

# %%
from tqdm import tqdm
X, y, Z = [], [], []

for path, emotion in tqdm(zip(test_df.FileName, test_df.Emotion), total=len(test_df.FileName)):
    file_path = test_path + '/' + path
    feature = get_features(file_path)
    X.append(feature)
    y.append(emotion) #dummy data
    Z.append(path) #filename
X = np.array(X)
y = np.array(y)
Z = np.array(Z)
# Out:
#   0%|                                                                                          | 0/700 [00:00<?, ?it/s]<ipython-input-3-32bb8b4d7431>:25: FutureWarning: Pass y=[-0.00397573 -0.00574587 -0.0055486  ...  0.01142031  0.00170693
#   0.        ], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))
#   0%|                                                                                  | 1/700 [00:00<06:20,  1.84it/s]<ipython-input-3-32bb8b4d7431>:25: FutureWarning: Pass y=[0.00864775 0.0097519  0.01087247 ... 0.00024919 0.0002335  0.        ], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))
# <ipython-input-3-32bb8b4d7431>:25: FutureWarning: Pass y=[-0.00882236  0.01206924  0.05435363 ...  0.00028805  0.00040704
#   0.        ], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))
#   0%|▎                                                                                 | 3/700 [00:00<02:13,  5.22it/s]<ipython-input-3-32bb8b4d7431>:25: FutureWarning: Pass y=[ 1.7393164e-05 -6.4030310e-06 -1.6411556e-06 ...  1.9369700e-06
#  -4.6178866e-06  0.0000000e+00], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))
# <ipython-input-3-32bb8b4d7431>:25: FutureWarning: Pass y=[ 0
0.        ], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))
# <ipython-input-3-32bb8b4d7431>:25: FutureWarning: Pass y=[-0.16586767 -0.193882   -0.17032959 ...  0.00381839  0.00267197
#   0.        ], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))
#  98%|██████████████████████████████████████████████████████████████████████████████▌ | 687/700 [00:41<00:00, 21.21it/s]<ipython-input-3-32bb8b4d7431>:25: FutureWarning: Pass y=[-0.15148433 -0.311687   -0.32480448 ...  0.00387373 -0.00053301
#   0.        ], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))
# <ipython-input-3-32bb8b4d7431>:25: FutureWarning: Pass y=[-0.00223349 -0.00284775 -0.00194857 ... -0.00196154 -0.00200403
#   0.        ], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))
# <ipython-input-3-32bb8b4d7431>:25: FutureWarning: Pass y=[ 0.00383675  0.00540754  0.00419756 ... -0.00278659 -0.00439322
#   0.        ], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))
#  99%|██████████████████████████████████████████████████████████████████████████████▊ | 690/700 [00:41<00:00, 18.80it/s]<ipython-input-3-32bb8b4d7431>:25: FutureWarning: Pass y=[ 0.0941378   0.14747505  0.14313386 ... -0.00095661 -0.00070582
#   0.        ], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))
# <ipython-input-3-32bb8b4d7431>:25: FutureWarning: Pass y=[-1.14629686e-01 -1.65633097e-01 -1.60503983e-01 ...  4.70362320e-05
#   1.37597264e-04  0.00000000e+00], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))
#  99%|███████████████████████████████████████████████████████████████████████████████ | 692/700 [00:41<00:00, 17.51it/s]<ipython-input-3-32bb8b4d7431>:25: FutureWarning: Pass y=[-0.02165796 -0.02377253 -0.01472526 ... -0.00040606 -0.00080684
#   0.        ], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))
# <ipython-input-3-32bb8b4d7431>:25: FutureWarning: Pass y=[ 0.00885118  0.01357745  0.01220628 ... -0.03285071 -0.03647762
#   0.        ], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))
#  99%|███████████████████████████████████████████████████████████████████████████████▎| 694/700 [00:41<00:00, 17.40it/s]<ipython-input-3-32bb8b4d7431>:25: FutureWarning: Pass y=[-0.00413791 -0.00486552 -0.00328961 ... -0.01050624 -0.01148989
#   0.        ], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))
# <ipython-input-3-32bb8b4d7431>:25: FutureWarning: Pass y=[0.03383619 0.05131542 0.04024934 ... 0.00325424 0.00329635 0.        ], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))
#  99%|███████████████████████████████████████████████████████████████████████████████▌| 696/700 [00:41<00:00, 15.77it/s]<ipython-input-3-32bb8b4d7431>:25: FutureWarning: Pass y=[0.04062878 0.11991245 0.17966066 ... 0.00494341 0.00439592 0.        ], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))
# <ipython-input-3-32bb8b4d7431>:25: FutureWarning: Pass y=[-0.00056047 -0.00040816 -0.00069976 ... -0.00147012 -0.00093493
#   0.        ], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))
# <ipython-input-3-32bb8b4d7431>:25: FutureWarning: Pass y=[-7.8433707e-02  2.8368303e-01 -9.6175626e-02 ... -2.8403827e-03
#   2.7969302e-04  0.0000000e+00], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))
# 100%|███████████████████████████████████████████████████████████████████████████████▉| 699/700 [00:41<00:00, 16.73it/s]<ipython-input-3-32bb8b4d7431>:25: FutureWarning: Pass y=[ 0.00035789  0.00040526  0.00034259 ... -0.00426142 -0.004426
#   0.        ], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   res = np.array(librosa.feature.mfcc(data, sample_rate, n_fft=2048, hop_length=512, n_mfcc=20))
# 100%|████████████████████████████████████████████████████████████████████████████████| 700/700 [00:41<00:00, 16.67it/s]

# %%
X.shape, y.shape, Z.shape
# Out:
# ((700, 20, 120), (700,), (700,))

# %% [markdown]
# # Scale data
#
# I scaled the data by a factor of 0.01.

# %%
X = X/100

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split, KFold

import keras
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from keras.utils import np_utils
from tensorflow.keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint

import warnings
if not os.sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# # Create OneHotEncoder

# %%
# As this is a multiclass classification problem onehotencoding our Y.
from sklearn.preprocessing import StandardScaler, OneHotEncoder
encoder = OneHotEncoder()
y = encoder.fit_transform(np.array(y).reshape(-1,1)).toarray()

# %% [markdown]
# # Predict on test data

# %%
saved_model = keras.models.load_model('./nlp_model.h5')

# %%
# predicting on test data.
pred_test = saved_model.predict(X)
print(pred_test)
y_pred = encoder.inverse_transform(pred_test)
print(y_pred)
# Out:
# 22/22 [==============================] - 1s 4ms/step
# [[6.42691020e-07 1.06287924e-04 1.53168148e-05 9.96254206e-01
#   3.62355937e-03]
#  [1.07539227e-14 1.98441612e-07 5.34468962e-11 1.64681282e-08
#   9.99999762e-01]
#  [8.39743661e-05 3.33222151e-02 9.04658635e-04 5.66559429e-05
#   9.65632498e-01]
#  ...
#  [1.26298051e-04 2.93389987e-02 9.70455766e-01 3.22179367e-05
#   4.66943311e-05]
#  [7.68873811e-01 3.53899226e-02 1.86616585e-01 6.92640664e-03
#   2.19328888e-03]
#  [8.89290310e-03 2.81765964e-02 4.63186949e-02 8.32714438e-01
#   8.38973373e-02]]
# [['neutral']
#  ['sad']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['neutral']
#  ['sad']
#  ['angry']
#  ['sad']
#  ['sad']
#  ['neutral']
#  ['sad']
#  ['sad']
#  ['neutral']
#  ['neutral']
#  ['angry']
#  ['sad']
#  ['happy']
#  ['angry']
#  ['sad']
#  ['sad']
#  ['neutral']
#  ['neutral']
#  ['happy']
#  ['sad']
#  ['sad']
#  ['sad']
#  ['fear']
#  ['happy']
#  ['sad']
#  ['sad']
#  ['fear']
#  ['happy']
#  ['sad']
#  ['sad']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['sad']
#  ['neutral']
#  ['sad']
#  ['sad']
#  ['sad']
#  ['happy']
#  ['sad']
#  ['angry']
#  ['happy']
#  ['angry']
#  ['neutral']
#  ['sad']
#  ['angry']
#  ['happy']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['sad']
#  ['angry']
#  ['neutral']
#  ['fear']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['angry']
#  ['happy']
#  ['sad']
#  ['neutral']
#  ['happy']
#  ['angry']
#  ['neutral']
#  ['sad']
#  ['sad']
#  ['sad']
#  ['sad']
#  ['neutral']
#  ['sad']
#  ['angry']
#  ['happy']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['happy']
#  ['neutral']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['neutral']
#  ['happy']
#  ['angry']
#  ['angry']
#  ['neutral']
#  ['neutral']
#  ['neutral']
#  ['angry']
#  ['neutral']
#  ['angry']
#  ['angry']
#  ['happy']
#  ['happy']
#  ['neutral']
#  ['happy']
#  ['neutral']
#  ['neutral']
#  ['angry']
#  ['angry']
#  ['neutral']
#  ['neutral']
#  ['angry']
#  ['angry']
#  ['happy']
#  ['angry']
#  ['angry']
#  ['neutral']
#  ['angry']
#  ['neutral']
#  ['happy']
#  ['sad']
#  ['angry']
#  ['sad']
#  ['neutral']
#  ['angry']
#  ['neutral']
#  ['angry']
#  ['neutral']
#  ['sad']
#  ['fear']
#  ['happy']
#  ['angry']
#  ['neutral']
#  ['angry']
#  ['sad']
#  ['neutral']
#  ['angry']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['angry']
#  ['angry']
#  ['angry']
#  ['happy']
#  ['neutral']
#  ['angry']
#  ['sad']
#  ['neutral']
#  ['neutral']
#  ['fear']
#  ['angry']
#  ['angry']
#  ['fear']
#  ['angry']
#  ['neutral']
#  ['angry']
#  ['sad']
#  ['fear']
#  ['sad']
#  ['fear']
#  ['sad']
#  ['happy']
#  ['angry']
#  ['neutral']
#  ['sad']
#  ['angry']
#  ['sad']
#  ['fear']
#  ['angry']
#  ['angry']
#  ['fear']
#  ['neutral']
#  ['fear']
#  ['angry']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['angry']
#  ['sad']
#  ['neutral']
#  ['angry']
#  ['happy']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['happy']
#  ['angry']
#  ['happy']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['angry']
#  ['fear']
#  ['neutral']
#  ['neutral']
#  ['neutral']
#  ['fear']
#  ['angry']
#  ['neutral']
#  ['sad']
#  ['neutral']
#  ['angry']
#  ['angry']
#  ['happy']
#  ['angry']
#  ['sad']
#  ['angry']
#  ['fear']
#  ['sad']
#  ['neutral']
#  ['happy']
#  ['fear']
#  ['sad']
#  ['neutral']
#  ['angry']
#  ['neutral']
#  ['neutral']
#  ['sad']
#  ['happy']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['neutral']
#  ['neutral']
#  ['angry']
#  ['angry']
#  ['happy']
#  ['happy']
#  ['angry']
#  ['fear']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['sad']
#  ['sad']
#  ['angry']
#  ['sad']
#  ['angry']
#  ['sad']
#  ['happy']
#  ['sad']
#  ['fear']
#  ['angry']
#  ['sad']
#  ['sad']
#  ['happy']
#  ['sad']
#  ['neutral']
#  ['fear']
#  ['neutral']
#  ['angry']
#  ['sad']
#  ['sad']
#  ['fear']
#  ['sad']
#  ['fear']
#  ['fear']
#  ['neutral']
#  ['angry']
#  ['fear']
#  ['angry']
#  ['fear']
#  ['neutral']
#  ['angry']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['happy']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['angry']
#  ['sad']
#  ['neutral']
#  ['fear']
#  ['neutral']
#  ['happy']
#  ['angry']
#  ['neutral']
#  ['angry']
#  ['angry']
#  ['neutral']
#  ['sad']
#  ['sad']
#  ['sad']
#  ['happy']
#  ['angry']
#  ['fear']
#  ['neutral']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['fear']
#  ['neutral']
#  ['neutral']
#  ['fear']
#  ['fear']
#  ['fear']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['happy']
#  ['happy']
#  ['angry']
#  ['sad']
#  ['angry']
#  ['neutral']
#  ['happy']
#  ['sad']
#  ['neutral']
#  ['angry']
#  ['neutral']
#  ['neutral']
#  ['angry']
#  ['sad']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['neutral']
#  ['angry']
#  ['neutral']
#  ['neutral']
#  ['neutral']
#  ['sad']
#  ['sad']
#  ['angry']
#  ['sad']
#  ['fear']
#  ['fear']
#  ['neutral']
#  ['neutral']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['angry']
#  ['neutral']
#  ['neutral']
#  ['neutral']
#  ['happy']
#  ['fear']
#  ['angry']
#  ['sad']
#  ['neutral']
#  ['angry']
#  ['fear']
#  ['happy']
#  ['fear']
#  ['happy']
#  ['sad']
#  ['angry']
#  ['neutral']
#  ['neutral']
#  ['sad']
#  ['angry']
#  ['neutral']
#  ['sad']
#  ['sad']
#  ['sad']
#  ['neutral']
#  ['neutral']
#  ['fear']
#  ['fear']
#  ['angry']
#  ['neutral']
#  ['angry']
#  ['sad']
#  ['happy']
#  ['angry']
#  ['sad']
#  ['angry']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['neutral']
#  ['angry']
#  ['sad']
#  ['neutral']
#  ['sad']
#  ['sad']
#  ['angry']
#  ['sad']
#  ['sad']
#  ['neutral']
#  ['sad']
#  ['angry']
#  ['neutral']
#  ['happy']
#  ['angry']
#  ['sad']
#  ['angry']
#  ['fear']
#  ['sad']
#  ['neutral']
#  ['happy']
#  ['sad']
#  ['happy']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['angry']
#  ['fear']
#  ['neutral']
#  ['sad']
#  ['neutral']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['neutral']
#  ['angry']
#  ['angry']
#  ['happy']
#  ['neutral']
#  ['happy']
#  ['neutral']
#  ['fear']
#  ['sad']
#  ['angry']
#  ['happy']
#  ['sad']
#  ['sad']
#  ['angry']
#  ['neutral']
#  ['angry']
#  ['neutral']
#  ['angry']
#  ['neutral']
#  ['happy']
#  ['angry']
#  ['sad']
#  ['neutral']
#  ['happy']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['sad']
#  ['neutral']
#  ['angry']
#  ['sad']
#  ['sad']
#  ['angry']
#  ['sad']
#  ['angry']
#  ['neutral']
#  ['sad']
#  ['fear']
#  ['neutral']
#  ['sad']
#  ['sad']
#  ['neutral']
#  ['fear']
#  ['sad']
#  ['neutral']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['neutral']
#  ['angry']
#  ['sad']
#  ['sad']
#  ['happy']
#  ['neutral']
#  ['sad']
#  ['neutral']
#  ['fear']
#  ['sad']
#  ['neutral']
#  ['angry']
#  ['sad']
#  ['neutral']
#  ['happy']
#  ['sad']
#  ['happy']
#  ['neutral']
#  ['neutral']
#  ['happy']
#  ['neutral']
#  ['neutral']
#  ['sad']
#  ['happy']
#  ['fear']
#  ['angry']
#  ['angry']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['sad']
#  ['neutral']
#  ['neutral']
#  ['neutral']
#  ['neutral']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['neutral']
#  ['sad']
#  ['neutral']
#  ['angry']
#  ['angry']
#  ['neutral']
#  ['happy']
#  ['angry']
#  ['neutral']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['neutral']
#  ['neutral']
#  ['happy']
#  ['sad']
#  ['happy']
#  ['fear']
#  ['angry']
#  ['fear']
#  ['happy']
#  ['angry']
#  ['angry']
#  ['fear']
#  ['sad']
#  ['neutral']
#  ['neutral']
#  ['fear']
#  ['neutral']
#  ['neutral']
#  ['sad']
#  ['sad']
#  ['happy']
#  ['sad']
#  ['happy']
#  ['neutral']
#  ['neutral']
#  ['neutral']
#  ['neutral']
#  ['angry']
#  ['sad']
#  ['neutral']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['happy']
#  ['angry']
#  ['happy']
#  ['angry']
#  ['angry']
#  ['neutral']
#  ['sad']
#  ['sad']
#  ['neutral']
#  ['angry']
#  ['angry']
#  ['neutral']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['neutral']
#  ['angry']
#  ['angry']
#  ['happy']
#  ['neutral']
#  ['angry']
#  ['sad']
#  ['happy']
#  ['angry']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['fear']
#  ['angry']
#  ['neutral']
#  ['neutral']
#  ['sad']
#  ['sad']
#  ['happy']
#  ['sad']
#  ['angry']
#  ['happy']
#  ['neutral']
#  ['sad']
#  ['neutral']
#  ['angry']
#  ['happy']
#  ['angry']
#  ['angry']
#  ['angry']
#  ['neutral']
#  ['angry']
#  ['sad']
#  ['sad']
#  ['neutral']
#  ['neutral']
#  ['neutral']
#  ['neutral']
#  ['angry']
#  ['neutral']
#  ['angry']
#  ['angry']
#  ['angry']
#  ['neutral']
#  ['happy']
#  ['sad']
#  ['happy']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['fear']
#  ['sad']
#  ['neutral']
#  ['neutral']
#  ['neutral']
#  ['neutral']
#  ['happy']
#  ['neutral']
#  ['fear']
#  ['angry']
#  ['neutral']
#  ['sad']
#  ['neutral']
#  ['sad']
#  ['neutral']
#  ['angry']
#  ['angry']
#  ['neutral']
#  ['sad']
#  ['sad']
#  ['sad']
#  ['angry']
#  ['neutral']
#  ['angry']
#  ['fear']
#  ['happy']
#  ['happy']
#  ['neutral']
#  ['fear']
#  ['happy']
#  ['neutral']
#  ['neutral']
#  ['sad']
#  ['sad']
#  ['angry']
#  ['angry']
#  ['sad']
#  ['angry']
#  ['neutral']
#  ['angry']
#  ['neutral']
#  ['fear']
#  ['angry']
#  ['neutral']
#  ['sad']
#  ['fear']
#  ['fear']
#  ['sad']
#  ['angry']
#  ['happy']
#  ['fear']
#  ['angry']
#  ['happy']
#  ['neutral']
#  ['happy']
#  ['sad']
#  ['fear']
#  ['sad']
#  ['neutral']
#  ['neutral']
#  ['neutral']
#  ['angry']
#  ['fear']
#  ['angry']
#  ['neutral']
#  ['neutral']
#  ['neutral']
#  ['happy']
#  ['angry']
#  ['sad']
#  ['happy']
#  ['neutral']
#  ['sad']
#  ['sad']
#  ['angry']
#  ['happy']
#  ['angry']
#  ['neutral']]

# %% [markdown]
# # Store data

# %%
df = pd.DataFrame(columns=['FileName','Predicted Emotion']) #,'Dummy Labels'])
df['FileName'] = Z
df['Predicted Emotion'] = y_pred.flatten()
#df['Dummy Labels'] = y_test.flatten()

# .csv format, no headers, sorted in ascending order by the first column (Do for submission csv)
df.sort_values(by=['FileName'], inplace=True)

# Cleaning (because of x3 attributes)
#df.drop_duplicates(inplace=True)
#df.drop_duplicates(subset='FileName', keep="last", inplace=True)

# Output save
df.to_csv("ouput_chris_nlp.csv", index=False, header=False)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df.head(100))
# Out:
#           FileName Predicted Emotion
# 0   0028c4fbc5.wav           neutral
# 1   00b924e5b4.wav               sad
# 2   0116a30694.wav               sad
# 3   014259dcfd.wav             angry
# 4   01bfa4103d.wav             angry
# 5   026c0f62db.wav             angry
# 6   02990f092b.wav             angry
# 7   02b750b8f1.wav               sad
# 8   03022e40b3.wav           neutral
# 9   03403158f8.wav               sad
# 10  035f9b2e70.wav             angry
# 11  044370bd33.wav               sad
# 12  04ec2f4600.wav               sad
# 13  04f22c7b9e.wav           neutral
# 14  0561683c1f.wav               sad
# 15  05d9201963.wav               sad
# 16  0606db6199.wav           neutral
# 17  065680dc7d.wav           neutral
# 18  07192d646f.wav             angry
# 19  076eb57ae9.wav               sad
# 20  0803950294.wav             happy
# 21  086c232666.wav             angry
# 22  08c6fbf5fc.wav               sad
# 23  090ad52a07.wav               sad
# 24  097debeccb.wav           neutral
# 25  09b8baab63.wav           neutral
# 26  0a6734bd4e.wav             happy
# 27  0a88c57e89.wav               sad
# 28  0b0e50ff37.wav               sad
# 29  0b164bd0ee.wav               sad
# 30  0b4103464d.wav              fear
# 31  0b6337a97c.wav             happy
# 32  0c3bed1111.wav               sad
# 33  0cb52871ee.wav               sad
# 34  0cf22ea53a.wav              fear
# 35  0d9d35a776.wav             happy
# 36  0dfb9e7f43.wav               sad
# 37  0e4866c1c2.wav               sad
# 38  0f2a2fe0e5.wav               sad
# 39  0f466523c3.wav             angry
# 40  0f891da266.wav             angry
# 41  102bd4be1e.wav               sad
# 42  109e4a2dca.wav               sad
# 43  1136cb1d4a.wav           neutral
# 44  1198fc4ca7.wav               sad
# 45  11e23248b7.wav               sad
# 46  1222d5b795.wav               sad
# 47  1229da1457.wav             happy
# 48  125249b9c0.wav               sad
# 49  12ec0dda4d.wav             angry
# 50  135587a143.wav             happy
# 51  13718a1ebc.wav             angry
# 52  13c400fe40.wav           neutral
# 53  13ed3237e0.wav               sad
# 54  145cf7718d.wav             angry
# 55  146dfa3589.wav             happy
# 56  1485cdaf9b.wav             angry
# 57  148f808fe9.wav             angry
# 58  14a6fb6744.wav               sad
# 59  14abb6aed0.wav               sad
# 60  17d884d538.wav             angry
# 61  18376cf721.wav           neutral
# 62  18a4cde3bd.wav              fear
# 63  1983c91ee3.wav               sad
# 64  19a65ca80f.wav             angry
# 65  19b303f99e.wav             angry
# 66  19d0b728eb.wav               sad
# 67  19d1f66688.wav             angry
# 68  1a37c04b86.wav             happy
# 69  1a7982dd20.wav               sad
# 70  1a9214fdd3.wav           neutral
# 71  1b85b3c3b1.wav             happy
# 72  1b8d05e14a.wav             angry
# 73  1bce484993.wav           neutral
# 74  1bda709a3a.wav               sad
# 75  1c2680fb50.wav               sad
# 76  1cfa067ff4.wav               sad
# 77  1d12abf3df.wav               sad
# 78  1d57977d94.wav           neutral
# 79  1dfe9f0daf.wav               sad
# 80  1e33517090.wav             angry
# 81  1e521f89a2.wav             happy
# 82  2086e77b92.wav             angry
# 83  2174cf7fac.wav             angry
# 84  21d08247fb.wav               sad
# 85  228f4dcae3.wav             happy
# 86  22a1ba9436.wav           neutral
# 87  235cbbd40f.wav             angry
# 88  23bbf68a2b.wav             angry
# 89  245ce0598d.wav               sad
# 90  256c95201b.wav           neutral
# 91  258ebef5be.wav             happy
# 92  259a8c80de.wav             angry
# 93  2668034254.wav             angry
# 94  27396875d2.wav           neutral
# 95  275fd50b47.wav           neutral
# 96  28482c389a.wav           neutral
# 97  28a3eae752.wav             angry
# 98  28b7eb6c60.wav           neutral
# 99  29542eb2e7.wav             angry
